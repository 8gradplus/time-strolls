# %%
import os
import sys
sys.path.append('..')
from pydantic import BaseModel
from typing import Optional, List
# todo use unified interface consistently (e.g location)
from api.model.place import PlaceCreate
from api.model.image import ImageCreate
from api.model.location import Podcast 
from config import config
import requests
from dotenv import load_dotenv
load_dotenv('../../deployment/credentials.prod')
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Resources:
# - https://www.znicenekostely.cz/objekt/detail/13352
# - https://www.zanikleobce.cz/

# %%
# local
HOST = 'http://0.0.0.0:8000/api'
API_KEY = 'secret'

# prod
#HOST = 'https://timestrolls.debtray.com/api'
#API_KEY = os.getenv('API_KEY')

# %%
HEADERS = {'X-API-Key': API_KEY}

class Topothek(BaseModel):
    url: str 

class LocationCreate(BaseModel):
    place: PlaceCreate
    podcast: Optional[Podcast] = None
    images: Optional[List[Topothek]] = []

def post_location(location: LocationCreate):
    r = requests.post(f'{HOST}/places', json=location.place.model_dump(), headers=HEADERS)
    print(f'Create location {location.place.name}: {r.status_code}')
    place_id = r.json().get('id')
    for image in location.images: 
        r = requests.post(f'{HOST}/images/topothek/', json={'url':image.url, 'place_id':place_id}, headers=HEADERS)
        print(f'Post image {image.url}: {r.status_code}')
    if location.podcast:
        r = requests.post(f'{HOST}/podcasts', json=location.podcast.model_dump() | dict(place_id=place_id), headers=HEADERS)
        print(f'Post podcast {location.podcast.url}: {r.status_code}')

# %%
unterurasch = LocationCreate(
    place=PlaceCreate(name='Unterurasch', 
                      lat=48.61017854015886, 
                      lon=14.04406485511563
                     ), 
    images=[
        Topothek(url='https://lichtenau.topothek.at/?doc=840955'),
        Topothek(url='https://lichtenau.topothek.at/?doc=564226'),
        Topothek(url='https://lichtenau.topothek.at/?doc=546072'),
        Topothek(url='https://lichtenau.topothek.at/?doc=546074'),
        Topothek(url='https://lichtenau.topothek.at/?doc=546065'),
        Topothek(url='https://lichtenau.topothek.at/?doc=430410'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=616754'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=951017'),
    ], 
    podcast=Podcast(title="Strohdach decken", 
                    owner="Fritz Bertlwieser",  
                    url="https://debtray.fra1.cdn.digitaloceanspaces.com/test/timestrolls/podcasts/767240b7-e0ec-48be-950b-49a8157f9db6.mp3")
    
)

oberuresch_chapel = LocationCreate(
    place=PlaceCreate(name='Waldkapelle Oberuresch', 
                      type='Chapel', 
                      lat=48.6113, 
                      lon=14.06166
                     ),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=739341'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500606'), 
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=739332'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=739311'),
    ]
)

oberuresch = LocationCreate(
    place=PlaceCreate(name='Oberuresch', 
                      lat=48.609008, 
                      lon=14.056219
                     ),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=742582'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=742432'), 
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=741744'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=651318'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=523740'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=499826'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1416256'), 
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1105447'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=747993'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=747998'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=541695'),
        
    ]
    
)

muckenschlag = LocationCreate(
    place=PlaceCreate(name='Muckenschlag', 
                      lat=48.618878, 
                      lon=14.047547),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=811050'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=811049'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=807686'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=799291'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=803298 '),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=802810'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=802020'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=799496'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=799429'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=798557'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=797893'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=798129'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=798103'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=798085'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=700040'),
    ]
)

sankt_thoma = LocationCreate(
    place=PlaceCreate(name='Sankt Thoma', 
                      lat=48.6412870685, 
                      lon=14.105554802),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1771855'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1547393'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1411296'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1358433'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1258019'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=936948'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1695349'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774852'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=515522'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1370280'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1355203'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1154801'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=979543'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=912776'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1085899'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=775307'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=980500'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=979542'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=953501'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=947906'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=947902'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=946834'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=946626'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=946469'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=926848'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=903949'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=912918'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=907897'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=907842'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=907832'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=907695'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=903817'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=899566'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=894150'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=857963'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=776203'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=709848'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=776206'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=775295'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=775293'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774884'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774850'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774745'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774513'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774349'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774327'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=774307'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=772619'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=772030'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=772628'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=771190'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=771188'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=734980'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=735456'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=734925'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=733780'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=733776'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=732653'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=731201'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=731199'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=727866'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=727828'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=725850'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=725765'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=725750'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=725829'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=722458'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1695101'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1694944'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507310'),
        
    ],
        
    podcast=Podcast(title="GAG83: 100 Jahre vor der Reformation – Jan Hus und die Hussitenkriege", 
                    owner="Geschichten aus der Geschichte", 
                    url="https://audio.podigee-cdn.net/543211-m-64d99e1b9312e44e27a75be845df3628.mp3")
)

# %%
asang = LocationCreate(
    place=PlaceCreate(name='Asang',
                      lat=48.626484, 
                      lon=14.052272),
    images=[
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323982'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=590939'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=2051472'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507288'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=2060971'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=963293'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507300'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507340'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500546'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507149'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500513'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507299'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686491'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=506926'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507290'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=543395'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507289'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1085842'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=534715'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=2060915'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1350112'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=541209'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1167817'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=788287'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=927012'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=540832'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1070979'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507304'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1755435'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686490'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=506934'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=558167'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1755423'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1010522'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497002'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507303'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=891263')
    ]
)


schmiedmuehle = LocationCreate(
    place=PlaceCreate(name='Schmiedmühle',
                      lat=48.62750, 
                      lon=14.04942),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=496979'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507296'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1675060'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=506928'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=507295')
    ]
)


rosenhuegel = LocationCreate(
    place=PlaceCreate(name='Rosenhügel',
                      lat=48.64514, 
                      lon=14.04886),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500524'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1414397'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1414392'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=537602'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=537600'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1003789'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500526'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500521'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500525'),
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500527'),
    ]
)


 	
untermarkschlag = LocationCreate(
    place=PlaceCreate(name='Untermarkschlag',
                      lat=48.63256, 
                      lon=14.03831),
    images=[
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=542532'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500639'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=591404'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=979284'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=526819'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500680'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=924897'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500647'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500648'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=542126'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500657'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500659'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1075701'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=526816'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500682'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500681'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500637'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1309465'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500675'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500688'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500687'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500669'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=696298'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500670'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=2040792'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=526813'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500638'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=695281'),
         Topothek(url='https://deutsch-reichenau.topothek.at/?doc=651579')
    ]
)


st_oswald = LocationCreate(
    place=PlaceCreate(name='Sankt Oswald',
                      lat=48.61903490532756, 
                      lon=14.030726480131019),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=2043183'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=1946494'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=964244'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=1400243'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=969375'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=908791'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=706275'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=432949'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=432932'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=368909'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=191239'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=187587'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=120792'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=79965'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=79978'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=79936'),
        Topothek(url='https://sankt-oswald.topothek.at/?doc=51847'),
    ]
)

 	 
luagmuehle = LocationCreate(
    place=PlaceCreate(name='Luagmühle',
                      lat=48.63389, 
                      lon=14.04631),
    images=[
        Topothek(url='https://deutsch-reichenau.topothek.at/?doc=529800')
    ]
)


obermarkschlag = LocationCreate(
    place=PlaceCreate(name='Obermarkschlag', 
                      lat=48.63731,
                      lon=14.03014), 
    images = [
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497908'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498263'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498266'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498279'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498280'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498287'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498289'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498380'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498382'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498384'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498386'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498406'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498407'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498415'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498417'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498423'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498424'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498428'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498434'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498435'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498441'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498449'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498455'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498456'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498462'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498465'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498467'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498468'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498469'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498470'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498474'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498480'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500654'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=523157'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=533507'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=533509'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=533519'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=555059'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=567050'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=591434'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=600022'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=696934'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=840067'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=840068'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=840069'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=840070'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=867417'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=867673'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=919776'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=994412'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=999196'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1033320'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1041396'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1044728'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1074810'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1171384'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1260980'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1280298'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1280299'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1280300'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1322888'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323492'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323559'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323569'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323739'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1331073'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1372664'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1405133'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1405197'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1408138'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1426351')
]
)

deutsch_reichenau = LocationCreate(
    place=PlaceCreate(name='Deutsch Reichenau', 
                      lat=48.61638,
                      lon=14.06916), 
    images = [
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497715'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497717'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497722'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497725'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497739'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497749'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497752'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497755'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497759'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497772'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497774'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497780'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497782'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497784'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497789'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497791'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497823'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497824'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497830'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497845'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497857'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497872'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497874'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497899'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497906'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497907'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497917'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497922'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497929'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497934'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497946'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497948'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497950'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497957'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497963'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497964'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497965'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497966'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497967'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497969'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497970'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497975'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497976'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497977'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497979'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497980'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497981'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497985'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497987'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497991'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497992'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497993'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497994'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497996'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497997'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=497998'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498002'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498004'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498065'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498066'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498069'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498074'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498080'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498082'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498084'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498089'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498092'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498093'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498094'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498095'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498099'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=498132'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500198'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500228'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500537'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500547'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500551'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500552'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=500559'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=515575'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=515595'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=516389'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=516392'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=522286'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=522483'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=522683'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=524831'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=525635'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=526004'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=533054'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=536336'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=538440'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=538793'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=540869'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=542127'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=549439'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=551043'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=558841'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=558929'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=559657'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=561401'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=561442'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=561794'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=562645'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=562664'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=566799'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=575248'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=577090'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=582310'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=584072'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=591658'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=595655'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=612846'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=615839'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=623066'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=625920'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=625930'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=625962'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=626419'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=627231'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=628188'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=628737'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=629812'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=631146'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=647974'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=648365'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=648366'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=648389'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=651579'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=657468'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=657481'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=657881'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=671038'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=671629'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=677805'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=678077'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=682441'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=682442'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=683366'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=683645'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=684169'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=684258'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=684543'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=684598'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686134'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686916'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686932'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686944'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686952'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=686953'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=687177'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=687350'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=687459'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=687964'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=687972'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=687974'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=689485'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=689942'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=692509'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=694885'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=694907'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=696294'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=696448'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=705053'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=709305'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=709306'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=709847'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=710488'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=710854'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=712371'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=737707'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=739006'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=752282'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=752295'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=753634'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=754716'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=755590'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=759443'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=768512'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=769797'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=850566'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=850632'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=882031'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=905135'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=919263'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=924935'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=926162'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=930636'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=936431'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=939709'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=942149'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=943054'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=943056'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=947979'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=947992'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=948000'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=949718'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=951017'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=964810'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=966095'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=966351'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=966574'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=966871'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=966903'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=983139'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=990038'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=992965'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=993046'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1001363'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1002097'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1003940'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1008023'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1008817'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1010230'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1019030'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1019214'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1019230'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1019231'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1019451'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1032176'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1067516'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1068658'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1074519'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1081513'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1094003'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1094273'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1111032'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1128477'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1130939'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1131529'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1141008'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1148321'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1152562'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1155674'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1157228'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1157236'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1157251'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1157838'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1158861'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1164222'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1167571'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1167573'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1167618'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1167686'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1167759'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1170908'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1180912'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1304859'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1304861'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1305021'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1305022'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1305460'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1305910'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1306133'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1309454'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1309614'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1311891'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1312583'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1312584'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1313865'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1313866'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1313868'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1314043'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1314300'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1314392'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1314436'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323150'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323856'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1323982'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1329101'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1348862'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1348865'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1348898'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1357486'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1398486'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1398515'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1398535'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1408119'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1461585'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1468246'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1512750'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1519650'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1535197'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1606583'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1616395'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1668221'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1694191'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=1907327'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=2030788'),
    Topothek(url='https://deutsch-reichenau.topothek.at/?doc=2104801')
]
)

# %%
# %%time

locations_1 = [unterurasch, oberuresch, oberuresch_chapel, muckenschlag, sankt_thoma]
locations_2 = [asang, schmiedmuehle, rosenhuegel, untermarkschlag, st_oswald, luagmuehle]
locations_3 = [obermarkschlag, deutsch_reichenau]
for location in locations_1 + locations_2 + locations_3: 
    post_location(location)
# Out:
# Create location Unterurasch: 200
# Post image https://lichtenau.topothek.at/?doc=840955: 200
# Post image https://lichtenau.topothek.at/?doc=564226: 200
# Post image https://lichtenau.topothek.at/?doc=546072: 200
# Post image https://lichtenau.topothek.at/?doc=546074: 200
# Post image https://lichtenau.topothek.at/?doc=546065: 200
# Post image https://lichtenau.topothek.at/?doc=430410: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=616754: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=951017: 200
# Post podcast https://debtray.fra1.cdn.digitaloceanspaces.com/test/timestrolls/podcasts/767240b7-e0ec-48be-950b-49a8157f9db6.mp3: 200
# Create location Oberuresch: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=742582: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=742432: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=741744: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=651318: 200
# ...

# %%
post_location(deutsch_reichenau)
# Out:
# Create location Deutsch Reichenau: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497715: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497717: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497722: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497725: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497739: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497749: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497752: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497755: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497759: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497772: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497774: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497780: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497782: 200
# Post image https://deutsch-reichenau.topothek.at/?doc=497784: 200
# ...

# %%
def upload_tour(path, name, description=None):
    url = f'{HOST}/tours/upload/'
    files = {"file": open(path, "rb")}
    data = {"name": name, "description": description}
    response = requests.post(url, data=data, files=files, headers=HEADERS)
    return response

# %%
r = upload_tour("/Users/viktor/Work/8gradplus/time-strolls/resources/gps/schwemmkanalweg_gross_komoot.gpx", "Schwemmkanalweg", "Grosse Runde")

# %%
r.status_code
# Out:
# 200

# %%
r.json()
